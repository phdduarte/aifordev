# %%
# !pip3 install langchain-community
# !pip3 install langchain-chroma
# !pip3 install langchain-openai
# !pip3 install langchain-text-splitters
# !pip3 install python-git
# Out:
# Requirement already satisfied: python-git in /Users/pedroduarte/dev/AIAGENT/myenv/lib/python3.12/site-packages (2018.2.1)
# Requirement already satisfied: send2trash in /Users/pedroduarte/dev/AIAGENT/myenv/lib/python3.12/site-packages (from python-git) (1.8.3)

# %%
from langchain_community.document_loaders.generic import GenericLoader
from langchain_community.document_loaders.parsers import LanguageParser
from langchain_text_splitters import Language, RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.chains.question_answering import load_qa_chain
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

import os
from git import Repo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#       9 from langchain.chains.combine_documents import create_stuff_documents_chain
#      11 import os
# ---> 12 from git import Repo
#
# ModuleNotFoundError: No module named 'git'
